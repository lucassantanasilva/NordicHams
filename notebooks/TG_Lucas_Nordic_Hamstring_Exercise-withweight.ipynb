# %% [markdown]
# <font color='red'> OBS: Os eixos no skillspector estão invertidos!! A coluna marcada como Eixo X representa o eixo Y e vice-versa. Caso o problema for resolvido no software ou no txt, lembrar de alterar o código também!

# %% [markdown]
# # Nordic Hamstring Exercise
#
# > Lucas Santana, Reginaldo Fukuchi
# > [Laboratory of Biomechanics and Motor Control](http://pesquisa.ufabc.edu.br/bmclab/)
# > Federal University of ABC, Brazil

# %% [markdown]
# <h1>Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importando-as-bibliotecas-necessárias" data-toc-modified-id="Importando-as-bibliotecas-necessárias-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importando as bibliotecas necessárias</a></span></li><li><span><a href="#Importando-os-arquivos-de-texto-e-do-Cortex" data-toc-modified-id="Importando-os-arquivos-de-texto-e-do-Cortex-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importando os arquivos de texto e do Cortex</a></span></li><li><span><a href="#Parâmetros-dos-segmentos-corporais" data-toc-modified-id="Parâmetros-dos-segmentos-corporais-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Parâmetros dos segmentos corporais</a></span><ul class="toc-item"><li><span><a href="#Dados-do-sujeito" data-toc-modified-id="Dados-do-sujeito-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dados do sujeito</a></span></li><li><span><a href="#Dados-da-coleta" data-toc-modified-id="Dados-da-coleta-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dados da coleta</a></span></li><li><span><a href="#Massa" data-toc-modified-id="Massa-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Massa</a></span></li><li><span><a href="#Comprimento" data-toc-modified-id="Comprimento-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Comprimento</a></span></li><li><span><a href="#Ângulo-dos-segmentos" data-toc-modified-id="Ângulo-dos-segmentos-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Ângulo dos segmentos</a></span></li><li><span><a href="#Centro-de-massa" data-toc-modified-id="Centro-de-massa-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Centro de massa</a></span></li><li><span><a href="#Velocidade-e-aceleração-do-centro-de-massa" data-toc-modified-id="Velocidade-e-aceleração-do-centro-de-massa-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Velocidade  e aceleração do centro de massa</a></span></li><li><span><a href="#Velocidade-a-aceleração-angular" data-toc-modified-id="Velocidade-a-aceleração-angular-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Velocidade a aceleração angular</a></span></li><li><span><a href="#Momento-de-Inercia" data-toc-modified-id="Momento-de-Inercia-3.3"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Momento de Inercia</a></span></li></ul></li><li><span><a href="#Dinâmica-Inversa" data-toc-modified-id="Dinâmica-Inversa-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dinâmica Inversa</a></span></li><li><span><a href="#Modelos-estáticos" data-toc-modified-id="Modelos-estáticos-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Modelos estáticos</a></span><ul class="toc-item"><li><span><a href="#Modelo-estático-completo" data-toc-modified-id="Modelo-estático-completo-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Modelo estático completo</a></span></li><li><span><a href="#Modelo-estático-simplificado" data-toc-modified-id="Modelo-estático-simplificado-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Modelo estático simplificado</a></span></li><li><span><a href="#Comparação-entre-os-modelos" data-toc-modified-id="Comparação-entre-os-modelos-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Comparação entre os modelos</a></span></li></ul></li><li><span><a href="#Dados-obtidos-do-Cortex-e-do-dinamômetro-isocinetico-(Biodex)" data-toc-modified-id="Dados-obtidos-do-Cortex-e-do-dinamômetro-isocinetico-(Biodex)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Dados obtidos do Cortex e do dinamômetro isocinetico (Biodex)</a></span><ul class="toc-item"><li><span><a href="#Cortex" data-toc-modified-id="Cortex-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Cortex</a></span></li><li><span><a href="#Biodex" data-toc-modified-id="Biodex-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Biodex</a></span></li><li><span><a href="#Comparação-dos-resultados" data-toc-modified-id="Comparação-dos-resultados-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Comparação dos resultados  </a></span></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>References</a></span></li></ul></div>

# %% [markdown]
# A flexão Nórdica é um exercício que aumenta a força excêntrica dos músculos isquiotibiais de forma mais eficiente do que outros exercícios aplicados a esse conjunto de músculos, em que é realizado com o voluntário inicialmente ajoelhado, com o tornozelo fixo e tronco na posição vertical. Essa fixação do tornozelo é feita tipicamente acima dos maléolos e pode ser realizada com o auxílio de um profissional ou com algum dispositivo. Posteriormente, o voluntário inicia o movimento de descida com a menor velocidade possível, até que encoste no chão na posição pronada.
#
# Este código irá calcular os valores de torque na articulação do torozelo e comparar com os valores obtidos pelo software Cortex

# %% [markdown]
# ## Importando as bibliotecas necessárias

# %% [markdown]
# As funções desenvolvidas especificamente para este código se encontram disponíveis no repositório do GitHub ().

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
from scipy import signal
import sys, os
sys.path.insert(1, r'./../functions')
from invdyn2d import invdyn2d
from detecta import detect_onset

# %% [markdown]
# ## Importando os arquivos de texto e do Cortex

# %% [markdown]
# Os dados contendo as posições das marcas durante a execução do movimento de flexão nórdica foram exportados em um arquivo de texto pelo software SkillSpector e os dados do dinamômetro isocinético, considerado o nosso padrão ouro, foram exportados em formato .anc pelo software Cortex.

# %%
# Arquivos de texto
filePath = Path('../data')
filename = filePath / 'Dados_coleta_with_weight2.txt'
data = pd.read_csv(filename,sep='\t', skiprows=5)
data.head()
# Out:
#    Joelho - X pos  Joelho - Y pos  Quadril - X pos  Quadril - Y pos  \
# 0          -0.697          16.055           34.009           10.323
# 1          -0.713          16.055           34.001           10.300
# 2          -0.729          16.055           33.993           10.282
# 3          -0.744          16.055           33.986           10.269
# 4          -0.758          16.055           33.979           10.260
#
#    C7 - X pos  C7 - Y pos  Barra - X pos  Barra - Y pos  Unnamed: 8
# 0      84.028       1.306          9.911        -17.145         NaN
# 1      83.985       1.318          9.851        -17.177         NaN
# 2      83.947       1.331          9.797        -17.206         NaN
# 3      83.916       1.345          9.747        -17.230         NaN
# 4      83.890       1.360          9.702        -17.250         NaN

# %% [markdown]
# ## Visualizar o problema

# %%
dataV = data.values[:,:-1] # delete the last column

# %% [markdown]
# <font color='red'> Arquivo.anc, lembrar de pegar no lab quando eu for

# %% [markdown]
# ## Parâmetros dos segmentos corporais

# %% [markdown]
# Um importante conjunto de propriedades mecânicas que auxilia no processo de elaborar um modelo para encontrar o torque no tornozelo é o conjunto dos parâmetros dos segmentos corporais. O corpo humano pode ser analisado como um sistema de corpos conectado, em que cada segmento do corpo possui geometria e parâmetros inerciais distintos. Essas variáveis tais como a massa, centro de massa e momentos de inércia são os chamados parâmetros dos segmentos corporais, sendo uma área da antropometria.
#
# A massa de um corpo é a quantidade de matéria contida nesse corpo, que independe da força da
# gravidade agindo neste corpo. Já o momento de inércia é a medida de como a massa de um corpo se distribui em relação a um determinado eixo que passa por um ponto, sendo equivalente a massa em uma rotação. Por fim, o raio de giro representa a distância do eixo a um ponto em que toda massa pode ser concentrada para obter o mesmo momento de inércia do objeto
#
# Com base nisso, foi utilizada a tabela proposta por Zatsiorsky e adaptada por de Leva para obter os parâmetros dos segmentos corporais. Inicialmente após mensurar a massa total dos sujeitos, foram utilizadas as porcentagens referentes a cada segmento. Em outras palavras, como cada parte do corpo representa uma porcentagem da massa total.

# %% [markdown]
# ### Dados do sujeito

# %% [markdown]
# Os valores de massa e altura foram mensurados antes da coleta, por meio de uma balança e um estadiômetro, respectivamente.

# %% [markdown]
# <font color='red'>Depois você pode ver tutoriais sobre isto mas talvez deixar na célula inicial parâmetros que serão modificados para cada sujeito. Tipo gravidade é uma constante que não varia entre os sujeitos por isto eu movi pra outra célula.</font>

# %%
M = 71.15    # massa em Kg
H = 1.531    # altura em m

# %% [markdown]
# ### Dados da coleta

# %% [markdown]
# Devido ao fato do video estar desentrelaçado, sua frequência ficou por volta de 60Hz. Consequentemente, cada frame possui uma duração de 0.016s, em que foram criadas variáveis com esse período e também com a duração final do vídeo.

# %% [markdown]
# <font color='red'>Depois a gente pode tentar deixar dt e tf automático baseado na dimensão dos dados do arquivo txt. O problema é que a webcam acho qu varia a freq de aquisição</font>

# %%
g = 9.80665  # m/s2, standard acceleration of free fall (ISO 80000-3:2006)
dt = 0.016 # duração de cada frame em s
tf = 6.896# duração do vídeo em s
t = np.arange(0, tf, dt) # vetor de tempo coma duração do vídeo
vector_lenght = t.size # Comprimento do vetor

# %% [markdown]
# Com os valores de tempo definidos, o próximo passo tomado foi definir as coordenadas para a articulação do joelho, do quadril da sétima vertebra da coluna cervical (C7) e da barra do dinamômetro isocinético.

# %%
# Coordenadas do tornozelo
lenght_shank = 0.246*H # Cálculo do comprimento da perna
Knee_posX = data['Joelho - Y pos'].values/100
Knee_posY = data['Joelho - X pos'].values/100
Ankle_posX = Knee_posX-lenght_shank
Ankle_posY = Knee_posY
# Coordenadas do joelho
Knee_posX = data['Joelho - Y pos'].values/100
Knee_posY = data['Joelho - X pos'].values/100
# Coordenadas do quadril
Hip_posX = data['Quadril - Y pos'].values/100
Hip_posY = data['Quadril - X pos'].values/100
# Coordenadas do C7
C7_posX = data['C7 - Y pos'].values/100
C7_posY = data['C7 - X pos'].values/100
# Coordenadas do eixo da barra
bar_axis_X = data['Barra - Y pos'].values/100
bar_axis_Y = data['Barra - X pos'].values/100

# %% [markdown]
# <font color='red'>Criei estes arrays p ficar mais fácil calcular a norma usando o np.linalg.norm</font>

# %%
Hip_pos = np.array([Hip_posX, Hip_posY]).T
Knee_pos= np.array([Knee_posX, Knee_posY]).T
C7_pos  = np.array([C7_posX, C7_posY]).T
bar_axis= np.array([bar_axis_X, bar_axis_Y]).T
Ankle_pos = np.array([Ankle_posX, Ankle_posY]).T

# %% [markdown]
# ### Massa

# %% [markdown]
# Com o valor de massa total obtido, foi utilizada a tabela de Zatsiorsky adaptada por de Leva para se obter a massa de cada segmento do corpo do sujeito. Para tal, foi usada como base a equação abaixo:
#
# <span class="notranslate">
# \begin{equation}
# m_{i} = M \cdot \text{bsp[i,mass]}
# \label{}
# \end{equation}
# </span>
#
# Em que $m_{i}$ representa a massa do segmento $i$ analisado, $M$ a massa total do sujeito e $bsp[i,mass]$ os valores percentuais tabelados para segmento. A linha a seguir apresenta a aplicação prática desta equação, além de mostrar em sua saída a massa de cada segmento.

# %% [markdown]
# <font color='red'>Estas frações de massa também poderiam ser puxadas direto de um arquivo txt que está na pasta data</font>

# %%
#BSP male values from Zatsiorsky's model adjusted by de Leva (1996)
m_thigh = M*0.1416
m_trunk = M*0.4346
m_head  = M*0.0694
m_shank = M*0.0433
m_upper_arm = M*0.0271
m_forearm = M*0.0162
m_hand = M*0.0061

print("Thigh:",np.around(m_thigh,3),"Kg")
print("Trunk:",np.around(m_trunk,3),"Kg")
print("Head:",np.around(m_head,3),"Kg")
print("Shank:",np.around(m_shank,3),"Kg")
print("Upper arm:",np.around(m_upper_arm,3),"Kg")
print("Forearm:",np.around(m_forearm,3),"Kg")
print("Hand:",np.around(m_hand,3),"Kg")
# Out:
# Thigh: 10.075 Kg
# Trunk: 30.922 Kg
# Head: 4.938 Kg
# Shank: 3.081 Kg
# Upper arm: 1.928 Kg
# Forearm: 1.153 Kg
# Hand: 0.434 Kg

# %% [markdown]
# ### Comprimento

# %% [markdown]
# O próximo parâmetro calculado foi o comprimento, em que foram obtidos os comprimentos nos eixos x e y e, posteriormente, a resultante dessas duas componentes. Esse procedimento foi feito para os segmentos da perna, coxa e quadril. Para os segmentos da mão, braço, antebraço e cabeça foram utilizados valores tabelados, devido ao fato de terem sido fixados apenas 4 marcas no sujeito.
#
# Para a coxa foi utilizada a seguinte equação com as posições do joelho e quadril, sendo realizada a média desse vetor para encontrar o comprimento do segmento:
#
# <span class="notranslate">
# \begin{equation}
# Lenght_{Thigh} = \sqrt{lenght_x^2+lenght_y^2} = \sqrt{(Hip_{posX} - Knee_{posX})^2 + (Hip_{posY} - Knee_{posY})}
# \label{}
# \end{equation}
# </span>
#
# Com os dados do quadril e da C7, o mesmo procedimento foi feito para obter o comprimento do tronco:
#
# <span class="notranslate">
# \begin{equation}
# Lenght_{Trunk} = \sqrt{lenght_x^2+lenght_y^2} = \sqrt{(C7_{posX} - Hip_{posX})^2 + (C7_{posY} - Hip_{posY})}
# \label{}
# \end{equation}
# </span>
#
# Por fim, para os segmentos restantes foram utilizados valores tabelados para o comprimento, representado de forma geral pela equação abaixo:
#
# <span class="notranslate">
# \begin{equation}
# Lenght_{i} = H \cdot \text{bsp[i,lenght]}
# \label{}
# \end{equation}
# </span>
#
# Em que $Lenght_{i}$ é o comprimento do segmento desejado, $H$ a altura do sujeito e $bsp[i,lenght]$ o valor tabelado para a altura do segmento $i$.

# %%
# Trunk Length
lenght_trunk = np.mean(np.linalg.norm(C7_pos-Hip_pos, axis=1))
print('Length of trunk is ' + str(np.round(lenght_trunk, 2)) + ' meters')
# Thigh Length
lenght_thigh = np.mean(np.linalg.norm(Hip_pos-Knee_pos, axis=1))
print('Length of thigh is ' + str(np.round(lenght_thigh, 2)) + ' meters')
# Shank Length
lenght_shank = np.mean(np.linalg.norm(Knee_pos-Ankle_pos, axis=1))
print('Length of shank is ' + str(np.round(lenght_shank, 2)) + ' meters')
# Out:
# Length of trunk is 0.5 meters
# Length of thigh is 0.35 meters
# Length of shank is 0.38 meters

# %% [markdown]
# <font color='red'>O comprimento da perna ficou maior que o da coxa, provavelmente por causa que foi estimado pela fração da altura do sujeito. Mais um motivo p gente medir ou colocar uma marca no tornozelo.</font>

# %% [markdown]
# ### Braço, antebraço, mão e cabeça
# Os parâmetros inerciais destes segmentos foram calculados assumindo que os mesmos se encontravam alinhados (paralelos) à orientação do tronco.

# %%
# Forearm
lenght_forearm = 0.145*H # Cálculo do comprimento do antebraço

# Upperarm
lenght_upperarm = 0.188*H # Cálculo do comprimento do braço

# Hand
lenght_hand = 0.108*H # Cálculo do comprimento da mão

# Head
lenght_head = 0.130*H # Cálculo do comprimento da cabeça

print ('\033[1m''Lenghts\n''\033[0m')
print('Thigh:',np.around(lenght_thigh,3),"m")
print('Trunk:',np.around(lenght_trunk,3),"m")
print('Shank:',np.around(lenght_shank,3), "m")
print('Forearm:',np.around(lenght_forearm,3),"m")
print('Upper arm:',np.around(lenght_upperarm,3),"m")
print('Hand:',np.around(lenght_hand,3),"m")
print("Head:",np.around(lenght_head, 3),"m")
# Out:
# Lenghts
#
# Thigh: 0.351 m
# Trunk: 0.5 m
# Shank: 0.377 m
# Forearm: 0.222 m
# Upper arm: 0.288 m
# Hand: 0.165 m
# Head: 0.199 m

# %%
# Trunk angle in relation to horizontal
trunk_ang = np.arctan2(C7_posY-Hip_posY, C7_posX-Hip_posX)

# %%
# Tip of the head
headTip_posY = np.sin(trunk_ang) * -lenght_head
headTip_posY = C7_posY - headTip_posY
headTip_posX = np.cos(trunk_ang) * -lenght_head
headTip_posX = C7_posX - headTip_posX
headTip_pos = np.array([headTip_posX, headTip_posY]).T

# %%
# Elbow coordinates
Elbow_posY = np.sin(trunk_ang) * lenght_upperarm
Elbow_posY = C7_posY - Elbow_posY
Elbow_posX = np.cos(trunk_ang) * lenght_upperarm
Elbow_posX = C7_posX - Elbow_posX
Elbow_pos = np.array([Elbow_posX, Elbow_posY]).T

# %%
# Wrist coordinates
Wrist_posY = np.sin(trunk_ang) * -lenght_forearm
Wrist_posY = Elbow_posY - Wrist_posY
Wrist_posX = np.cos(trunk_ang) * -lenght_forearm
Wrist_posX = Elbow_posX - Wrist_posX
Wrist_pos = np.array([Wrist_posX, Wrist_posY]).T

# %%
# knuckle coordinates
Knuckle_posY = np.sin(trunk_ang) * -lenght_hand
Knuckle_posY = Wrist_posY - Knuckle_posY
Knuckle_posX = np.cos(trunk_ang) * -lenght_hand
Knuckle_posX = Wrist_posX - Knuckle_posX
Knuckle_pos = np.array([Knuckle_posX, Knuckle_posY]).T

# %% [markdown]
# ## Visualizar o problema
# Plotar a posição das marcas e dos segmentos em um instante (-30) do ciclo.

# %%
plt.figure(figsize=(10,6))
plt.plot([headTip_pos[-30,0], C7_pos[-30,0], Hip_pos[-30,0],Knee_pos[-30,0],Ankle_pos[-30,0]],
         [headTip_pos[-30,1], C7_pos[-30,1], Hip_pos[-30,1],Knee_pos[-30,1],Ankle_pos[-30,1]], 'b-')
plt.plot(headTip_pos[-30,0], headTip_pos[-30,1], 'kv', label='headTip')
plt.plot(C7_pos[-30,0], C7_pos[-30,1], 'bo', label='C7')
plt.plot(Hip_pos[-30,0], Hip_pos[-30,1], 'ro', label='Hip')
plt.plot(Knee_pos[-30,0], Knee_pos[-30,1], 'ko', label='Knee')
plt.plot(Ankle_pos[-30,0], Ankle_pos[-30,1], 'go', label='Ankle')
plt.plot(Elbow_pos[-30,0], Elbow_pos[-30,1], 'yo', label='Elbow')
plt.plot(Wrist_pos[-30,0], Wrist_pos[-30,1], 'mo', label='Wrist')
plt.plot(Knuckle_pos[-30,0], Knuckle_pos[-30,1], 'rv', label='Knuckle')
plt.plot(bar_axis[-30,0], bar_axis[-30,1], 'k*', label='Bar axis')
plt.xlim([-0.5,1.25])
plt.ylim([-0.1,1.2])
plt.xlabel('Horizontal [m]')
plt.ylabel('Vertical [m]')
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Ângulo dos segmentos

# %% [markdown]
# Com o objetivo de garantir que o sujeito realizou a flexão nórdica de forma correta, os ângulos entre cada segmento e o solo foram calculados. De forma ideal, é desejado que os ângulos da coxa e do tronco sejam muito próximos ou mesmo iguais. Para o cálculo dos ângulos foi usada a equação geral a seguir:
#
# <span class="notranslate">
# $$ \theta_{i} = arctan\left(\frac{LenghtY_{i}}{LenghtX_{i}}\right) $$
# </span>
#
# Em seguida esses valores foram convertidos de radianos para graus.

# %%
theta_thigh = np.arctan2(Hip_posY-Knee_posY,Hip_posX-Knee_posX) * (180 / np.pi)
theta_trunk = np.arctan2(C7_posY-Hip_posY,C7_posX-Hip_posX) * (180 / np.pi)
theta_shank = np.arctan2(Knee_posY-Ankle_posY,Knee_posX-Ankle_posX) * (180 / np.pi)
plt.figure(figsize= [10,5])
plt.plot(t,theta_thigh,label='Coxa')
plt.plot(t,theta_trunk,label='Tronco')
plt.legend(loc='best')
plt.xlabel('Tempo [s]')
plt.ylabel('Ângulo [°]')
plt.title('Ângulo dos segmentos em relação ao solo')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# De modo a garantir que realmente a diferença entre os ângulos da coxa e do tronco não apresentam diferença significativa, foi calculada a variação percentual entre esses dois ângulos ao longo do tempo,como pode ser visto na equação a seguir
#
# <span class="notranslate">
# $$ \mathbf{var_{per}} = \left(\frac{\theta_{thigh}}{\theta_{trunk}} - 1\right) \cdot 100 $$
# </span>

# %%
var_per = ((theta_thigh/theta_trunk) - 1)*100
plt.figure(figsize= [10,5])
plt.plot(t,var_per,label='Variação')
plt.legend(loc='best')
plt.xlabel('Tempo [s]')
plt.ylabel('Variação [%]')
plt.title('Variação percentual entre os ângulos da coxa e do tronco')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Centro de massa

# %% [markdown]
# Outro importante parâmetro a ser estudado neste projeto é o centro de massa, definido como o ponto (posição) onde a soma dos vetores que ligam este ponto a cada partícula, ponderada por sua massa, é zero, em que a massa (a massa inercial) é uma medida quantitativa da resistência de um objeto à aceleração linear. Os valores utilizados para encontrar o centro de massa dos segmentos pode foram obtidos da tabela do modelo de Zatsiorsky adaptado por de Leva em 1996

# %%
bsp_Zm = pd.read_csv('./../data/BSPmale_ZdeLeva.txt', index_col=0, sep='\t')
display(bsp_Zm)
# Out:
#                Endpoints    Mass  CM Long  Rg Sag  Rg Trans  Rg Long
# Segment
# Head           VERT-MIDG  0.0694   0.5976   0.362     0.376    0.312
# Trunk          SUPR-MIDH  0.4346   0.4486   0.372     0.347    0.191
# Upper trunk    SUPR-XYPH  0.1596   0.2999   0.716     0.454    0.659
# Middle trunk   XYPH-OMPH  0.1633   0.4502   0.482     0.383    0.468
# Lower trunk    OMPH-MIDH  0.1117   0.6115   0.615     0.551    0.587
# Upper arm        SJC-EJC  0.0271   0.5772   0.285     0.269    0.158
# Forearm          EJC-WJC  0.0162   0.4574   0.276     0.265    0.121
# Hand            WJC-MET3  0.0061   0.7900   0.628     0.513    0.401
# Thigh            HJC-KJC  0.1416   0.4095   0.329     0.329    0.149
# Shank            KJC-AJC  0.0433   0.4395   0.251     0.246    0.102
# Foot           HEEL-TTIP  0.0137   0.4415   0.257     0.245    0.124
# Head 2         VERT-CERV  0.0694   0.5002   0.303     0.315    0.261
# ...

# %% [markdown]
# Tendo isso em vista, como os segmentos da mão, braço e antebraço não possuem marcas, foram utilizados uma série de cálculos para encontrar seus respectivos centros de massa e, posteriormrnte, seus momentos de inércia. O primeiro desses cálculos foi encontrar a altura do pulso, cotovelo e do ombro, para usar como pontos distal e proximal dos segmentos. Por fim, foram utilizados os valores "CM Long" para esses 3 segmentos.

# %% [markdown]
# <font color='red'>Acho que aqui, as coordenadas desconhecidas vc precisa usar a articulação distal ou proximal do segmento da marca. Por exemplo, para o cotovelo vc deveria usar o ombro e não o joelho. O ombro deveria usar a marca do quadril, e assim por diante. Tente recalcular assim e veja se melhora</font>

# %% [markdown]
# ![Dimensions-of-body-segments-relative-to-height-16.jpg](attachment:Dimensions-of-body-segments-relative-to-height-16.jpg)

# %%
# Altura do ombro em relação ao quadril
shoulder_height = 0.288*H
shoulder_height_y = Hip_posY + shoulder_height*np.sin(theta_trunk*(np.pi/180))
shoulder_height_x = Hip_posX + shoulder_height*np.cos(theta_trunk*(np.pi/180))
shoulder_height_vector = np.array([shoulder_height_x,shoulder_height_y])

# Altura do cotovelo em relação ao ombro
elbow_height = 0.188*H
elbow_height_y = shoulder_height_y - elbow_height*np.sin(theta_trunk*(np.pi/180))
elbow_height_x = shoulder_height_x - elbow_height*np.cos(theta_trunk*(np.pi/180))
elbow_height_vector = np.array([elbow_height_x, elbow_height_y])

# Altura do pulso em relação ao cotovelo
upperarm_height_y = elbow_height_y + lenght_forearm*np.sin(theta_trunk*(np.pi/180))
upperarm_height_x = elbow_height_x + lenght_forearm*np.cos(theta_trunk*(np.pi/180))
upperarm_height_vector = np.array([upperarm_height_x, upperarm_height_y])

# Cálculo do CM Long para o braço, antebraço e mão
forearm_CMLong = 0.4574*lenght_forearm
upperarm_CMLong = 0.5772*lenght_upperarm
hand_CMLong = 0.7900*lenght_hand

# %% [markdown]
# Posteriormente à isso, as variáveis criadas até agora foram usadas para definir os pontos distal e próximal dos segmentos restantes, sendo eles a perna, coxa, tronco e cabeça.

# %%
# Posições diatais e proximais
r_thigh_prox = np.array([Hip_posX,Hip_posY]).T
r_thigh_dis = np.array([Knee_posX,Knee_posY]).T
r_trunk_prox = np.array([Hip_posX,Hip_posY]).T
r_trunk_dis = np.array([C7_posX,C7_posY]).T
r_shank_prox = np.array([Knee_posX,Knee_posY]).T
r_shank_dis =np.array([Knee_posX-lenght_shank,Knee_posY]).T
r_head_prox = np.array([C7_posX,C7_posY]).T
r_head_dis = np.array([C7_posX + lenght_head*np.cos(theta_trunk*(np.pi/180)),C7_posY + lenght_head*np.sin(theta_trunk*(np.pi/180))]).T

# %% [markdown]
# Com todos os pontos calculados, foi utilizada a equação abaixo para obter o centro de massa de cada segmento:
#
# <span class="notranslate">
# \begin{equation}
# rcm_{i} = r_{i,p} + \text{bsp[i,cmp]} \cdot (r_{i,d}-r_{i,p})
# \label{}
# \end{equation}
# </span>
#
# Onde $r_{i,p}$ e $\:r_{i,d}$ são as posições proximal e distal do segmento $i$.

# %%
# Centro de massa para os segmentos em x e y
# Antebraço
rcm_forearm_x = elbow_height_x + forearm_CMLong*np.cos(theta_thigh*(np.pi/180))
rcm_forearm_y = elbow_height_y + forearm_CMLong*np.sin(theta_thigh*(np.pi/180))
# Braço
rcm_upperarm_x = shoulder_height_x - upperarm_CMLong*np.cos(theta_thigh*(np.pi/180))
rcm_upperarm_y = shoulder_height_y - upperarm_CMLong*np.sin(theta_thigh*(np.pi/180))
# Mão
rcm_hand_x = upperarm_height_x + hand_CMLong*np.cos(theta_thigh*(np.pi/180))
rcm_hand_y = upperarm_height_y + hand_CMLong*np.sin(theta_thigh*(np.pi/180))

# Centro de massa total
rcm_thigh  = r_thigh_prox + 0.4095*(r_thigh_dis-r_thigh_prox)
rcm_trunk   = r_trunk_prox + 0.4486*(r_trunk_dis-r_trunk_prox)
rcm_shank  = r_shank_prox + 0.4395*(r_shank_dis-r_shank_prox)
rcm_head  = r_head_prox + 0.5976*(r_head_dis-r_head_prox)
rcm_forearm = np.array([rcm_forearm_x, rcm_forearm_y]).T
rcm_upperarm = np.array([rcm_upperarm_x, rcm_upperarm_y]).T
rcm_hand = np.array([rcm_hand_x, rcm_hand_y]).T
rcm_total = ((m_thigh*rcm_thigh) + (m_trunk*rcm_trunk) + (m_forearm*rcm_forearm)+ (m_upper_arm*rcm_upperarm) + (m_hand*rcm_hand)+  (m_head*rcm_head))/(m_upper_arm + m_forearm + m_hand + m_head + m_thigh + m_trunk)

# %%
# Representação geométrica dos cálculos feitos
plt.rc('axes',  labelsize=14, linewidth=1.5) 
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)
plt.rc('lines', markersize=8) 
hfig, hax = plt.subplots(1, 1, figsize=(10, 6))

# bones and joints

# center of mass of each segment
plt.plot(rcm_thigh[:,0],rcm_thigh[:,1], 'green', label='CM thigh')
plt.plot(rcm_trunk[:,0],rcm_trunk[:,1], 'blue', label='CM Trunk')
plt.plot(rcm_head[:,0],rcm_head[:,1], 'orange', label='CM Head')
# total center of mass
plt.plot(rcm_total[:,0],rcm_total[:,1], 'red', label='total center of mass')
hax.legend(frameon=False, loc='upper left', fontsize=12, numpoints=1)

hax.set_xlim(0,1.1)
hax.set_ylim(0,1.3)
hax.set_xlabel('x [m]')
hax.set_ylabel('y [m]')
hax.set_title('Determination of center of mass', fontsize=16)
hax.grid()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Velocidade e aceleração do centro de massa

# %% [markdown]
# De modo a verificar o comportamento do centro de massa ao longo do tempo, foram calculadas as derivadas do centro de massa para obter suas respectivas velocidades

# %%
vcm_thigh = (rcm_thigh[2:,:] - rcm_thigh[0:-2,:])/(2*dt)
vcm_trunk = (rcm_trunk[2:,:] - rcm_trunk[0:-2,:])/(2*dt)
vcm_shank = (rcm_shank[2:,:] - rcm_shank[0:-2,:])/(2*dt)
vcm_total = (rcm_total[2:,:] - rcm_total[0:-2,:])/(2*dt)
# Adicionando elementos para corrigir a dimensão após a derivada
vcm_thigh = np.vstack((vcm_thigh, vcm_thigh[-1, :], vcm_thigh[-1, :]))
vcm_trunk = np.vstack((vcm_trunk, vcm_trunk[-1, :], vcm_trunk[-1, :]))
vcm_shank = np.vstack((vcm_shank, vcm_shank[-1, :], vcm_shank[-1, :]))
vcm_total = np.vstack((vcm_total, vcm_total[-1, :], vcm_total[-1, :]))

# %% [markdown]
# De forma análoga, foram realizados os mesmos procedimentos para que a aceleração do centro de massa pudesse ser analisada ao longo do exercício de flexão nórdica

# %%
acm_thigh = (vcm_thigh[2:,:] - vcm_thigh[0:-2,:])/(2*dt)
acm_trunk = (vcm_trunk[2:,:] - vcm_trunk[0:-2,:])/(2*dt)
acm_shank = (vcm_shank[2:,:] - vcm_shank[0:-2,:])/(2*dt)
acm_total = (vcm_total[2:,:] - vcm_total[0:-2,:])/(2*dt)
# Adicionando elementos para corrigir a dimensão após a derivada
acm_thigh = np.vstack((acm_thigh, acm_thigh[-1, :], acm_thigh[-1, :]))
acm_trunk = np.vstack((acm_trunk, acm_trunk[-1, :], acm_trunk[-1, :]))
acm_shank = np.vstack((acm_shank, acm_shank[-1, :], acm_shank[-1, :]))
acm_total = np.vstack((acm_total, acm_total[-1, :], acm_total[-1, :]))

# %% [markdown]
# ### Velocidade a aceleração angular

# %% [markdown]
# Como os ângulos da coxa e do tronco são determinantes para a validação do estudo, o mesmo processo de derivada foi utilizado para encontrar as velocidade e acelerações angulares. Além disso, a aceleração angular é um componente necessáriopara o cálculo do torque na articulação do tornozelo

# %%
theta_thigh = theta_thigh*(np.pi/180) # convert back to radians
theta_trunk = theta_trunk*(np.pi/180) # convert back to radians

# %%
#Finding the angular velocity
vtheta_thigh = (theta_thigh[2:] - theta_thigh[0:-2])/(2*dt)
vtheta_trunk = (theta_trunk[2:] - theta_trunk[0:-2])/(2*dt)
# Adicionando elementos para corrigir a dimensão após a derivada
vtheta_thigh = np.hstack((vtheta_thigh, vtheta_thigh[-1], vtheta_thigh[-1]))
vtheta_trunk = np.hstack((vtheta_trunk, vtheta_trunk[-1], vtheta_trunk[-1]))

# %%
#Finding the angular acceleration
atheta_thigh = (vtheta_thigh[2:] - vtheta_thigh[0:-2])/(2*dt)
atheta_trunk = (vtheta_trunk[2:] - vtheta_trunk[0:-2])/(2*dt)
# Adicionando elementos para corrigir a dimensão após a derivada
atheta_thigh = np.hstack((atheta_thigh, atheta_thigh[-1], atheta_thigh[-1]))
atheta_trunk = np.hstack((atheta_trunk, atheta_trunk[-1], atheta_trunk[-1]))

# %%
# Gráfico da velocidade angular
size_vcm = np.size(vcm_trunk)
new_t = t
fig, ax = plt.subplots(1, 1, figsize=(12,4))
ax.plot(new_t,vtheta_thigh, label = 'Coxa')
ax.plot(new_t,vtheta_trunk, label = 'Tronco')
plt.grid()
plt.xlabel('Tempo (s)')
plt.ylabel(r'Velocidade angular(rad/s)')
ax.legend(loc='best')
plt.suptitle('Velocidade angular dos segmentos', fontsize=15);

# Gráfico da aceleração angular
size_vcm = np.size(atheta_thigh)
new_t2 = t
fig, ax = plt.subplots(1, 1, figsize=(12,4))
ax.plot(new_t2,atheta_thigh, label = 'Coxa')
ax.plot(new_t2,atheta_trunk, label = 'Tronco')
plt.grid()
plt.xlabel('Tempo (s)')
plt.ylabel(r'Aceleração angular (rad/s²)')
ax.legend(loc='best')
plt.suptitle('Aceleração angular dos segmentos', fontsize=15);
# Out:
# <img src="data:image/png;base64,..." width="1200">
# <img src="data:image/png;base64,..." width="1200">

# %% [markdown]
# ### Momento de Inercia

# %% [markdown]
# O último parâmetro a ser abordado neste trabalho é o momento de inércia, definido como uma medida quantitativa da resistência à aceleração rotacional em torno de um eixo de uma distribuição de massa no espaço, em que, além dele, precisamos do raio de giro, que é a quantidade que é dada na tabela de parâmetros do segmento corporal, quando falamos de uma fração do comprimento do segmento.
#
# É importante ressaltar que para o cálculo do momento de inércia do tronco foram considerados, além do tronco, ambas asmão, braços e antebraços. De forma análoga, foram considerados ambas as coxas e pernas para seus respectivos momentos de inércia. A seguiinte equação foi utilizada para esse cálculo
#
# <span class="notranslate">
# \begin{equation}
# I_{i,cm} = M \cdot \text{bsp[i,mass]} \cdot \left(\text{bsp[i,rgcm]} \cdot ||r_{i,d}-r_{i,p}||\right)^2
# \label{}
# \end{equation}
# </span>
#
# Em que $M$ é a massa total da pessoa, $||r_{i,d}-r_{i,p}||$ o comprimento do segmento $i$ analisado, $bsp[i,rgcm]$ e $bsp[i,mass]$ os valores tabelados para o raio de giro e a massa de cada segmento, caso o usuário  não tenha calculado os valores de massa anteriormente.

# %%
# Raio de giro
Rg_thigh = 0.329
Rg_trunk = 0.372
Rg_head = 0.362
Rg_shank = 0.251

# Momento de inércia
Icm_thigh = (m_thigh*2)*((Rg_thigh*(np.mean(np.linalg.norm(r_thigh_dis-r_thigh_prox, axis=1)))**2)) #Sag
Icm_trunk = (m_trunk+m_forearm*2+m_hand*2+m_upper_arm*2)*((Rg_trunk*(np.mean(np.linalg.norm(r_trunk_dis-r_trunk_prox, axis=1)))**2)) #Sag 
Icm_shank = (m_shank*2)*((Rg_shank*(np.mean(np.linalg.norm(r_shank_dis-r_shank_prox, axis=1)))**2))
Icm_head = (m_head)*((Rg_head*(np.mean(np.linalg.norm(r_head_dis-r_head_prox, axis=1)))**2))

# Resultados dos cálculos
print ('\033[1m''Momentos de Inércia\n''\033[0m')
print('Thigh:',np.around(Icm_thigh,3),"kgm2")
print('Trunk:',np.around(Icm_trunk,3),"kgm2")
print('Shank:',np.around(Icm_shank,3), "kgm2")
print("Head:",np.around(Icm_head, 3),"kgm2")
# Out:
# Momentos de Inércia
#
# Thigh: 0.815 kgm2
# Trunk: 3.528 kgm2
# Shank: 0.219 kgm2
# Head: 0.071 kgm2

# %% [markdown]
# ## Dinâmica Inversa

# %% [markdown]
# A partir da posição e orientação dos segmentos do corpo, da medição das forças externas é possível estimar as forças e torques internos responsáveis por causar os movimentos analisados, por meio da abordagem da dinâmica inversa. Esse método combina as medidas cinemáticas, obtidas por um sistema de captura de movimento, com as forças externas ao movimento, obtidas por meio de plataformas de força e parâmetros inerciais dos segmentos, para estimar as forças e torques nas articulações, sendo usado em modelos com mais de um segmento.
#
# Para simplificar o problema, os segmentos do corpo humano são considerados corpos rígidos cuja deformação é desconsiderada, o que implica que as distâncias entre todos os pares de pontos nesse corpo,além de sua massa total, são consideradas constantes.
#
# Como resolver as equações para encontrar as forças e torques nas articulações de forma manual é um processo demorado e pode levar à erros, foi utilizada a função `invdyn2d.py`, que fornece a força e torque do segmento desejado, em que foi aplicada três vezes, oara a cabeça, tronco e coxa.

# %% [markdown]
# <font color='red'> QUAL É A DIFF ENTRE AS DUAS CÉLULAS ABAIXO DO CÁLCULO DA DINAMICA INVERSA?

# %%
# Cabeça
Fp_head, Mp_head = invdyn2d(rcm_head, r_head_dis, r_head_prox, acm_trunk, atheta_trunk, m_head, Icm_head, np.array([0,0]), 0)
# Tronco
Fp_trunk, Mp_trunk = invdyn2d(rcm_trunk, r_trunk_dis, r_trunk_prox, acm_trunk, atheta_trunk, m_trunk, Icm_trunk,  -Fp_head, -Mp_head)
# Coxa
Fp_thigh, Mp_thigh = invdyn2d(rcm_thigh, r_thigh_prox, r_thigh_dis, acm_thigh, atheta_thigh, m_thigh, Icm_thigh, -Fp_trunk, -Mp_trunk)

# %%
# Cabeça
Fp_head, Mp_head = invdyn2d(rcm_head[0:len(acm_trunk)], r_head_dis[0:len(acm_trunk)], r_head_prox[0:len(acm_trunk)], acm_trunk, atheta_trunk, m_head, Icm_head, np.array([0,0]), 0)
# Tronco
MT_trunk = m_trunk +(m_forearm*2) + (m_hand*2) + (m_upper_arm*2)
Fp_trunk, Mp_trunk = invdyn2d(rcm_trunk[0:len(acm_trunk)], r_trunk_dis[0:len(acm_trunk)], r_trunk_prox[0:len(acm_trunk)], acm_trunk, atheta_trunk, MT_trunk, Icm_trunk,  -Fp_head, -Mp_head)
# Coxa
MT_thigh = (m_thigh*2)
Fp_thigh, Mp_thigh = invdyn2d(rcm_thigh[0:len(acm_trunk)], r_thigh_prox[0:len(acm_trunk)], r_thigh_dis[0:len(acm_trunk)], acm_thigh, atheta_thigh, MT_thigh, Icm_thigh, -Fp_trunk, -Mp_trunk)

# %%
# plot data
hfig, hax = plt.subplots(2, 2, sharex = True, squeeze=True, figsize=(9, 5))
hax[0, 0].plot(new_t2, Fp_trunk[:, [0, 1]], linewidth=2)
hax[0, 0].legend(('Fx','Fy'), frameon=False)
hax[0, 0].set_ylabel('Força - Quadril [N]')
hax[0, 0].grid()
hax[0, 1].plot(new_t2, Mp_trunk, linewidth=2)
hax[0, 1].legend(['Mp_trunk'], frameon=False)
hax[0, 1].set_ylabel('Torque - Quadril [Nm]')
hax[0, 1].grid()
hax[1, 0].plot(new_t2, Fp_thigh[:, [0, 1]], linewidth=2)
hax[1, 0].legend(('Fx','Fy'), frameon=False)
hax[1, 0].set_ylabel('Força - Joelho [N]')
hax[1, 0].grid()
hax[1, 1].plot(new_t2, Mp_thigh, linewidth=2)
hax[1, 1].legend(['Mp_thigh'], frameon=False)
hax[1, 1].set_ylabel('Torque - Joelho[Nm]')
hax[1, 0].set_xlabel('Time [s]'), hax[1, 1].set_xlabel('Time [s]')
hax[1, 1].grid()
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# Com o torque no joelho obtido, o próximo passo foi encontrar o torque no isocinético, em que foi usada uma simples equação de torque para tal considerando que a perna estava paralela à horizontal:
#
# <span class="notranslate">
# \begin{equation}
# M_{i} = F_{i} \cdot \text{d}
# \label{}
# \end{equation}
# </span>
#
# Em que $M_{i}$ é o torque na articulação, $F_{i}$ a força aplicada e $\text{d}$ a distância entre o ponto até a aplicação da força.

# %% [markdown]
# ### Calcular a distância entre o joelho e o bar axis
# Esta distância não deveria mas varia no tempo devido às incertezas na medição, por exemplo, quando você digitaliza as marcas introduz um erro neste comprimento. Então a gente deveria usar todos os valores e não apenas uma constante.

# %%
knee2bar_length = np.linalg.norm(bar_axis-Knee_pos, axis=1)

# %%
# DEPOIS VERIFICAR ESSES DOIS VALORES (0.36 E 0.31)
Fteste = Mp_thigh/knee2bar_length
Mteste = Fteste*0.329
print('Mean Iso Moment: ', np.mean(Mteste), 'Nm')
print('Min Iso Moment: ', np.min(Mteste), 'Nm')
print('Max Iso Moment: ', np.max(Mteste), 'Nm')
print('Amplitude: ', np.max(Mteste) - np.min(Mteste), 'Nm')
# Out:
# Mean Iso Moment:  37.09667573567653 Nm
# Min Iso Moment:  -52.63772789908769 Nm
# Max Iso Moment:  245.81839348627773 Nm
# Amplitude:  298.4561213853654 Nm

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))
plt.suptitle('Iso Moment', fontsize=20);
plt.plot(new_t2,Mteste, label = 'Iso Moment', color = 'red')
plt.grid()
plt.xlabel('time (s)')
plt.ylabel('Moment (Nm)')
ax.legend(loc='best')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Modelos estáticos

# %% [markdown]
# Além da dinâmica inversa, foram elaborados modelos mais simples para estimar o torque, em que após os cálculos serão feitas comparações entre todos os modelos, de modo a verificar a eficácia desses modelos mais simples.

# %% [markdown]
# ### Modelo estático completo

# %% [markdown]
# Esse primeiro modelo simplificado utiliza a mesma equação de torque geral anterior, em que a distância será do joelho até o centro de massa total da pessoa. Esse centro de massa considera ambos os braços, antebraços, mãos e coxas para seu cálculo, em que é calculado usando a equação abaixo:
#
# <span class="notranslate">
# $$ \vec{r}_{cm} = \frac{\sum\limits_{i=1}^nm_i{\vec{r}_i}}{m_T} $$
# </span>
#
# Em que $\vec{r}_{cm}$ representa o centro de massa total, $\sum\limits_{i=1}^nm_i{\vec{r}_i}$ o produto da massa pelo vetor posiçãode cada segmento pelo seu respectivo centro de massa e $m_T$ a massa total. A obtenção do torque foi feita com base no seguinte Diagrama de Corpo Livre.

# %% [markdown]
# ![DCL.jpg](attachment:DCL.jpg)

# %%
# Massa total dos segmentos considerados
MTotal = (m_thigh*2) + m_trunk + m_head + (m_forearm*2) + (m_hand*2) + (m_upper_arm*2)

# Centro de massa do modelo estático
rcm_total_static = (((m_thigh*2)*rcm_thigh) + ((m_trunk+m_forearm*2+m_hand*2+m_upper_arm*2)*rcm_trunk) + (m_head*rcm_head))/MTotal

# Distância do joelho até o centro de massa total
L_rcm_Total = rcm_total_static - r_thigh_dis
L_rcm = np.sqrt(L_rcm_Total[:,0]*L_rcm_Total[:,0] + L_rcm_Total[:,1]*L_rcm_Total[:,1])

# Cálculo do torque (VERIFICAR ESSES VALORES ABAIXO DE FORÇA E TORQUE DEPOIS NO LAB)
# M = MTotal*g*L_rcm*np.cos(theta_thigh*(np.pi/180))
M = MTotal*g*L_rcm*np.cos(theta_thigh) - (m_shank*2)*g*(lenght_shank/2)*np.cos(theta_shank)
F = M/knee2bar_length
Mt = F*0.329

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t[0:len(Mt)],Mt,label = 'Moment')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Moment (Nm)')
ax.legend(loc='best')
plt.suptitle('Modelo estático completo', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Modelo estático simplificado

# %% [markdown]
# Esse segundo modelo é ainda mais simples, pois não considera o centro de massa total. Nele a pessoa é considerada uma barrra, em que seu comprimento éa soma dos comprimentos da coxa, tronco e cabeça. Como o centro de massa de uma barra fica na metade de seu comprimento, a distância seria simplesmente a metade do comprimento dessa barra, em que o torque calculado seria dado por:
#
# <span class="notranslate">
# $$ M = m_T \cdot g \cdot \left(\frac{L}{2}\right)  \cdot cos(\theta_{thigh}) - m_{shank}\cdot g \cdot \left(\frac{L_{shank}}{2}\right)\cdot cos(\theta_{shank})$$
# </span>
#
# Em que $g$ é a aceleração da gravidade, $L$ o comprimento total da barra calculado e $\theta$ é o ângulo da coxa. O cálculo do torque seguiu o mesmo DCL adotado anteriormente.

# %%
# Cálculo do comprimento total da barra
L = lenght_head + lenght_thigh + lenght_trunk

# Cálculo do torque (VERIFICAR ESSES VALORES ABAIXO DE FORÇA E TORQUE DEPOIS NO LAB)
#M2 = MTotal*g*(L/2)*np.cos(theta_thigh*(np.pi/180))
M2 = MTotal*g*(L/2)*np.cos(theta_thigh) - (m_shank*2)*g*(lenght_shank/2)*np.cos(theta_shank)
F2 = M2/knee2bar_length
Mt2 = F2*0.329

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t,Mt2, label = 'Moment')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Moment (Nm)')
ax.legend(loc='best')
plt.suptitle('Modelo estático simplificado', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Comparação entre os modelos

# %% [markdown]
# Para verificar como os modelos simplificados se comportam em relação ao método da dinâmica inversa, ambos os resultados foram plotados juntos.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t,Mt,label = 'Modelo estático completo')
ax.plot(t,Mt2,label = 'Modelo estático simplificado')
ax.plot(new_t2,Mteste, label = 'Iso Moment', color = 'red')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Comparação entre os modelos', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# De forma semelhante ao que foi feito com a variação angular, foi calculada a variação percentual entre os valores de torque pela dinânica inversa e usando o modelo simplificado, em que o resultado pode ser visyto a seguir.

# %%
var_per = ((Mt[0:len(Mteste)]/Mteste) - 1)*100
plt.figure(figsize= [10,6])
plt.plot(new_t2,var_per,label='Variação')
plt.legend(loc='best')
plt.xlabel('Tempo [s]')
plt.ylabel('Variação [%]')
plt.title('Variação percentual entre torques pela dinâmica inversa e pelo modelo simplificado')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Dados obtidos do Cortex e do dinamômetro isocinetico (Biodex)

# %% [markdown]
# Neste último item, os dados da coleta obtidos pelo software Cortex e pelo dinamômetro isocinetico serão importados. Estes dados foram registrados ao mesmo tempo em que a coleta foi realizada com a câmera e as marcas refletivas.
#
# A seguir serão apresentados os resultados mensurados pelo Cortex e pelo Biodex para, em seguida, ser feita uma comparação entre ambos com os resultados obtidos pela dinâmica inversa.

# %% [markdown]
# ### Cortex

# %% [markdown]
# O arquivo gerado pelo cortex está no formato .anc, sendo possível mesmo assim ser aberto como comando `np.loadtxt`. Além disso, os dados foram alocados em variáveis para serem usados posteriormente.

# %%
# Lendo o arquivo de dados
data_cortex=np.loadtxt(r'./../data/trialwithweight2.anc', skiprows=11)

# Sampling freq=300 Hz
# Inserindo os dados em suas respectivas variáveis 
time = data_cortex[:,0] # nome
freq_analog = int(1/(np.mean(np.diff(time))))
position = data_cortex[:,1] # posição
velocity = data_cortex[:,2] # velocidade
torque = data_cortex[:,3] # torque
sync = data_cortex[:,4]

# %%
plt.figure(figsize=(10,6))
plt.plot(time, torque)
plt.xlabel('Time [s]')
plt.ylabel('Torque [V]')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Com o objetivo de comparar o torque de maneira eficaz, este foi convertido para Nm, em que o processo de conversão pode ser vsito na linha de código a seguir.

# %%
t_torque = np.arange(0, 30, 0.005)#Frequência de 200Hz
t_torque = np.linspace(0,30,torque.shape[0])
#t_torque = time #Frequência de 200Hz
torque_v = (torque)*(10/65535)
torque_ftlbs = torque_v/0.0098
torque_nm = torque_ftlbs/0.73756 # torque convertido em Nm

# %% [markdown]
# Por fim, é possível visualizar o comportamento do torque pelo Cortex na figura abaixo

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t_torque,torque_nm,label = 'Torque - Cortex')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Torque - Cortex', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Detect signal onset

# %%
from detecta import detect_onset

# %%
inds_cortex = detect_onset(torque_nm, 0, n_above=10, n_below=0, show=False)
inds_Mt = detect_onset(Mt, 0, n_above=10, n_below=0, show=False)
inds_Mteste = detect_onset(Mteste, 0, n_above=10, n_below=0, show=False)

# %%
t_torque[7*300]
# Out:
# 10.501750291715286

# %%
dt = 0.016 # duração de cada frame em s

# %%
1/dt
# Out:
# 62.5

# %%
freq_analog
# Out:
# 300

# %%
fig, ax = plt.subplots(3, 1, figsize=(10,6))

ax[0].plot(t_torque[inds_cortex[0][0]:2100],torque_nm[inds_cortex[0][0]:2100],label = 'Torque - Cortex')
ax[1].plot(t[inds_Mt[0][0]:],Mt[inds_Mt[0][0]:],label = 'Torque - Static')
ax[2].plot(new_t2[inds_Mteste[0][0]:],Mteste[inds_Mteste[0][0]:], label = 'Torque - Dynamic')
ax[0].grid()
ax[0].set_xlim([2,10])
ax[0].set_ylim([0,200])
ax[0].set_ylabel('Cortex (Nm)')
ax[1].grid()
ax[1].set_xlim([2,10])
ax[1].set_ylim([0,200])
ax[1].set_ylabel('Mt (Nm)')
ax[2].grid()
ax[2].set_xlim([2,10])
ax[2].set_ylim([0,200])
ax[2].set_ylabel('Mteste (Nm)')
plt.xlabel('time (s)')
plt.suptitle('Comparação dos torques obtidos', fontsize=30);
plt.show()
fig.savefig(r'../comp_torques.png')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t_torque[inds_cortex[0][0]:],torque_nm[inds_cortex[0][0]:],label = 'Torque - Cortex')
ax.plot(t[inds_Mt[0][0]:],Mt[inds_Mt[0][0]:],label = 'Torque - Static')
plt.plot(new_t2[inds_Mteste[0][0]:],Mteste[inds_Mteste[0][0]:], label = 'Torque - Dynamic')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Comparação dos torques obtidos', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t_torque,torque_nm,label = 'Torque - Cortex')
ax.plot(t,Mt,label = 'Torque - Static')
plt.plot(new_t2,Mteste, label = 'Torque - Dynamic')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Comparação dos torques obtidos', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Biodex

# %% [markdown]
# De forma análoga ao que foi feito com o Cortex, sod dados do Biodex foram importados e os valores de torque armazenados em uma variável, servindo de base para a criação do seu respectivo vetor de tempo.

# %%
#Reading
data_biodex=np.loadtxt(r'./../data/RFukuchiISOMRDATA2_2.txt')

# Obtendo a variável de torque
torque_biodex = data_biodex[0:9000:3]
t_torque2 = np.arange(0, 30, 0.01) #Frequência de 100Hz
t_torque2 = np.linspace(0, 30, torque_biodex.shape[0])

# %% [markdown]
# Por fim, é possível visualizar o comportamento do torque pelo Biodex na figura abaixo

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t_torque2,-torque_biodex/10,label = 'Torque - Biodex')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Torque - Biodex', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Posteriormente, foi feita uma comparação comos valores brutos de torque obtidos por todos os métodos, sem que nenhum tratamento tenha sido empregado nos dados

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

ax.plot(t_torque,torque_nm,label = 'Torque - Cortex')
ax.plot(t_torque2,-torque_biodex/10,label = 'Torque - Biodex')
ax.plot(t,Mt,label = 'Torque - Static')
plt.plot(new_t2,Mteste, label = 'Torque - Dynamic')
ax.grid()
plt.xlabel('time (s)')
plt.ylabel(r'Torque (Nm)')
ax.legend(loc='best')
plt.suptitle('Comparação dos torques obtidos', fontsize=30);
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Considerando apenas os valores positivos de torque dos modelos

# %%
iMt_Gt0 = np.where(Mt>0) # indices greater than zero
iMteste_Gt0 = np.where(Mteste>0) # indices greater than zero

# %%
Mt2 = Mt[iMt_Gt0]
Mteste2 = Mteste[iMteste_Gt0]
Mbiodex = -torque_biodex/10
Mbiodex2 = Mbiodex[320:]

# %%
# new time arrays
t_Mt = t[iMt_Gt0]
t_Mteste = t[iMteste_Gt0]
t_biodex = t_torque2[320:]

# %%
plt.figure()
plt.plot(t_Mt,Mt2)
plt.plot(t_Mteste,Mteste2)
plt.plot(t_biodex,Mbiodex2)
plt.grid()
plt.show()
# Out:
# <ipython-input-164-b2c5beb51860>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <img src="data:image/png;base64,..." width="640">

# %%
t_peak = np.argmax(Mbiodex2)/100
t_peak
# Out:
# 4.83

# %%
# find closes value in array
t_peak_Mt = np.argmin(np.abs(t_Mt - t_peak))
t_peak_Mt
# Out:
# 116

# %%
t_peak_Mtest = np.argmin(np.abs(t_Mteste - t_peak))
t_peak_Mtest
# Out:
# 170

# %%
plt.figure()
plt.plot(t_Mt[:t_peak_Mt],Mt2[:t_peak_Mt])
plt.plot(t_Mteste[:t_peak_Mtest],Mteste2[:t_peak_Mtest])
plt.plot(t_biodex[:np.argmax(Mbiodex2)],Mbiodex2[:np.argmax(Mbiodex2)])
plt.grid()
plt.show()
# Out:
# <ipython-input-167-9724925a0078>:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# <img src="data:image/png;base64,..." width="640">

# %%
from tnorma import tnorma

# %%
Mtn, tn, indie = tnorma(Mt2[:t_peak_Mt], step=1, k=3, smooth=1, show=False)
# Out:
# C:\Users\Reginaldo\miniconda3\lib\site-packages\tnorma\tnorma.py:207: RuntimeWarning: invalid value encountered in multiply
#   yn = np.empty([tn.size, y.shape[1]]) * np.NaN

# %%
Mtesten, tn, indie = tnorma(Mteste2[:t_peak_Mtest], step=1, k=3, smooth=1, show=False)

# %%
Mbiodexn, tn, indie = tnorma(Mbiodex2[:np.argmax(Mbiodex2)], step=1, k=3, smooth=1, show=False)

# %% [markdown]
# ## Plotar as comparações

# %%
plt.figure(figsize=(10,6))
plt.title('Comparação dos torques no joelho')
plt.plot(tn, Mtn,'b', label='Estático')
plt.plot(tn, Mtesten,'r', label='Dinâmico')
plt.plot(tn, Mbiodexn,'k', label='Referência')
plt.xlim([-1,101])
plt.xlabel('% do ciclo')
plt.ylabel('Nm')
plt.legend()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.savefig('lucas.png')

# %% [markdown]
# ### Comparação dos resultados

# %% [markdown]
# Para que possa ser feita a comparação entre as curvas de torque, é necessário que os dados estejam normalizados. Para tal, foi utilizada a função `detect_onset` que permite acessar os termos do vetor que possuem valores acima de um ponto estipulado. Posteriormente, esse intervalo com valores acima foi inserido em um segundo vetor com 100 termos, representando todo o procedimento de coleta (indo de 0 até 100%).

# %%
# Detect events

# Cortex
inds = detect_onset(torque_nm, 10, n_above=10, n_below=0, show=False)
xx = torque_nm[inds[0][0]:inds[0][1]]
t  = np.linspace(0, 100, len(xx))  # time vector for the original data
tn = np.linspace(0, 100, 101)
yn = np.empty(shape=(101))
yn[:] = np.interp(tn, t, xx)

# Biodex
torque_bio = -torque_biodex/10
inds = detect_onset(torque_bio, 10, n_above=10, n_below=0, show=False)
xx = torque_bio[inds[0][0]:inds[0][1]]
t  = np.linspace(0, 100, len(xx))  # time vector for the original data
tn2 = np.linspace(0, 100, 101)
yn2 = np.empty(shape=(101))
yn2[:] = np.interp(tn2, t, xx)

# %% [markdown]
# <font color='red'> POR ALGUM MOTIVO OS VETORES DE TORQUE DO ESTATICO E DINAMICO DERAM ERRO AO USAR O MÉTODO DO DETECT ONSET. POR ESSE MOTIVO, FOI USADO O DECIMATE PARA DEIXAR AMBOS COM 100 TERMOS.

# %%
# Mteste
Mteste_pos = Mteste[100:len(Mteste)]
Mteste_decimate = signal.decimate(Mteste_pos, 3, n=None, ftype='iir', axis=- 1, zero_phase=True)
Mteste_decimate_neg = signal.decimate(Mteste, 4, n=None, ftype='iir', axis=- 1, zero_phase=True)
# Mt
Mt_pos = Mt[100:len(Mt)]
Mt_decimate = signal.decimate(Mt_pos, 3, n=None, ftype='iir', axis=- 1, zero_phase=True)
Mt_decimate_neg = signal.decimate(Mt, 4, n=None, ftype='iir', axis=- 1, zero_phase=True)

# %% [markdown]
# Para comparar os gráficos gerados, foram utilizados primeiro somente os valores positivos de torque do estático e dinâmico.

# %%
plt.figure()
plt.plot(yn,label='Cortex')
plt.plot(yn2,label='Biodex')
plt.plot(Mteste_decimate,label='Dinâmico')
plt.plot(Mt_decimate,label='Estático')
plt.legend(loc='best')
plt.title('Torques no tornozelo - Somente valores positivos')
plt.ylabel('Torque [Nm]')
plt.xlabel('%')
plt.grid()
plt.show()

# %% [markdown]
# Em seguida foram plotadas as curvas completas, incluindo a parcela negativa do modelo estático e dinâmico.

# %%
plt.figure()
plt.plot(yn,label='Cortex')
plt.plot(Mteste_decimate_neg,label='Dinâmico')
plt.plot(Mt_decimate_neg,label='Estático')
plt.legend(loc='best')
plt.title('Torques no tornozelo - Todos os valores')
plt.ylabel('Torque [Nm]')
plt.xlabel('%')
plt.grid()
plt.show()

# %% [markdown]
# ## References
